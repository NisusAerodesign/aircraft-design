# %%
import numpy as np
import src.pre_selection_plotter as ps

unit = ps.unit

# %%
my_aircraft = ps.aircraft_selection(
    'My airplane',
    first_range=6000.0,
    second_range=300.0,
    LDmax=15.8,
    sfc_cruise=18.2,
    sfc_sea_level=12.0,
    wing_spain=20.7,
    wing_area=49,
)

print(my_aircraft)
# Out:
# Airplane: MY AIRPLANE
# ...
# first range: 6000.0 km
# second range: 300.0 km
#
# AR: 8.74
# Wing area: 49 m²
# Wing wet area: 412.37 m²
# Wing spain: 20.7 m
# +----------------+
# |W0  : 16_587 Kg |
# |Wf  :  5_795 kg |
# |We  :  9_007 kg |
# |W1W0:  0.97000  |
# |W2W1:  0.98050  |
# |W3W2:  0.74996  |
# |W4W3:  0.99110  |
# |W5W4:  0.99500  |
# |W6W5:  0.98050  |
# |W7W6:  0.98572  |
# |W8W7:  0.99110  |
# |W9W8:  0.99500  |
# +----------------+

# %%
f, ax = my_aircraft.plot_constraint_diagram(
    Range_takeoff=900,
    Range_land=900,
    CL_max=2.5,
    imperial_units=True,
    V_stall_kmph=190,
    V_vertical_kmph=30,
    bbox_to_anchor=(1.19, 0.7),
    CL_takeoff_per_CL_max=0.85
)

f.show()
# Out:
# /tmp/ipykernel_623879/748183251.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %%
# Engines to view
HTF7500E = ps.Engine(
    name='HTF7500E',
    thrust=31.30e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dotted',
    color='red',
)

HTF735 = ps.Engine(
    name='HTF735',
    thrust=32.57e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dotted',
    color='green',
)

HTF7700L = ps.Engine(
    name='HTF7700L',
    thrust=33.60e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dotted',
    color='blue',
)

HTF7250G = ps.Engine(
    name='HTF7250G',
    thrust=33.91e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dotted',
    color='yellow',
)

PW306D1 = ps.Engine(
    name='PW306D1',
    thrust=25.60e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashed',
    color='red',
)

PW306C = ps.Engine(
    name='PW306C',
    thrust=25.67e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashed',
    color='green',
)

PW306D = ps.Engine(
    name='PW306D',
    thrust=26.28e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashed',
    color='blue',
)

PW307A = ps.Engine(
    name='PW307A',
    thrust=28.49e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashed',
    color='yellow',
)

PW308A = ps.Engine(
    name='PW308A',
    thrust=30.69e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashed',
    color='magenta',
)

PW308C = ps.Engine(
    name='PW308C',
    thrust=31.14e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashed',
    color='cyan',
)

AE3007C = ps.Engine(
    name='AE 3007 C',
    thrust=31.32e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashdot',
    color='red',
)

AE3007A = ps.Engine(
    name='AE 3007 A',
    thrust=42.30e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='dashdot',
    color='green',
)

CF34_3B = ps.Engine(
    name='CF34-3B',
    thrust=38.32e3 * unit.lbf,
    number_of_engines=2,
    imperial_units=True,
    linestyle='solid',
    color='red',
)

engine_list = [
    HTF7500E,
    HTF735,
    HTF7700L,
    HTF7250G,
    PW306D1,
    PW306C,
    PW306D,
    PW307A,
    PW308A,
    PW308C,
    AE3007C,
    AE3007A,
    CF34_3B,
]

# %%
# Planes to compare
Praetor500 = ps.Plane(
    'Praetor 500',
    17.04e3 * unit.lb,
    49 * (unit.ft**2),
    2 * 31.3e3 * unit.lbf,
    True,
    'blue',
)

Challenger3500 = ps.Plane(
    'Challenger 3500',
    18.40e3 * unit.lb,
    48.5 * (unit.ft**2),
    2 * 32.57e3 * unit.lbf,
    True,
    'red',
)

G280 = ps.Plane(
    'G280',
    17.90e3 * unit.lb,
    46 * (unit.ft**2),
    2 * 33.91e3 * unit.lbf,
    True,
    'green',
)

Citation_Longitude = ps.Plane(
    'Citation Longitude',
    17.90e3 * unit.lb,
    49.9 * (unit.ft**2),
    2 * 33.6e3 * unit.lbf,
    True,
    'magenta',
)

plane_list = [
    Praetor500,
    Challenger3500,
    G280,
    Citation_Longitude,
]

# %%
# Plot
f, ax = my_aircraft.plot_select_engine(
    Range_takeoff=900,
    Range_land=900,
    CL_max=2.5,
    Engines=engine_list,
    Planes=plane_list,
    V_stall_kmph=190,
    imperial_units=True,
    V_vertical_kmph=30,
    bbox_to_anchor=(1.35, 0.92)
)
#ax.set_xlim([70, 80])
ax.set_ylim([0.31, 0.53])
f.show()
# Out:
# /tmp/ipykernel_623879/3727347170.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %%
my_aircraft.thrust_to_weight_ratio = 0.3807
my_aircraft.wing_load = 3591.0

print(my_aircraft)
# Out:
# Airplane: MY AIRPLANE
# ...
# first range: 6000.0 km
# second range: 300.0 km
#
# AR: 8.5
# Wing area: 50.04 m²
# Wing wet area: 409.33 m²
# Wing spain: 20.62 m
#
# T/W0: 0.381
# W0/S: 3_591.0 N/m²
# +----------------+
# |W0  : 18_323 Kg |
# |Wf  :  6_402 kg |
# |We  : 10_137 kg |
# |W1W0:  0.97000  |
# |W2W1:  0.98050  |
# |W3W2:  0.74996  |
# |W4W3:  0.99110  |
# |W5W4:  0.99500  |
# |W6W5:  0.98050  |
# |W7W6:  0.98572  |
# |W8W7:  0.99110  |
# |W9W8:  0.99500  |
# +----------------+
